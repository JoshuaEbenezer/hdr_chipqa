# %%
import time
import pandas as pd
from utils.hdr_utils import hdr_yuv_read
from utils.csf_utils import blockwise_csf,windows_csf
from joblib import Parallel,delayed
import numpy as np
import cv2
import queue
import glob
from colour.models import eotf_PQ_BT2100
import os
import time
import scipy.ndimage
import joblib
from scipy.stats import gmean
import sys
import matplotlib.pyplot as plt
import ChipQA.niqe 
import ChipQA.save_stats
from numba import jit,prange
import argparse
from skimage.util.shape import view_as_blocks
C=1
def gen_gauss_window(lw, sigma):
    sd = np.float32(sigma)
    lw = int(lw)
    weights = [0.0] * (2 * lw + 1)
    weights[lw] = 1.0
    sum = 1.0
    sd *= sd
    for ii in range(1, lw + 1):
        tmp = np.exp(-0.5 * np.float32(ii * ii) / sd)
        weights[lw + ii] = tmp
        weights[lw - ii] = tmp
        sum += 2.0 * tmp
    for ii in range(2 * lw + 1):
        weights[ii] /= sum
    return weights
def compute_image_mscn_transform(image, C=1, avg_window=None, extend_mode='constant'):
    if avg_window is None:
      avg_window = gen_gauss_window(3, 7.0/6.0)
    assert len(np.shape(image)) == 2
    h, w = np.shape(image)
    mu_image = np.zeros((h, w), dtype=np.float32)
    var_image = np.zeros((h, w), dtype=np.float32)
    image = np.array(image).astype('float32')
    scipy.ndimage.correlate1d(image, avg_window, 0, mu_image, mode=extend_mode)
    scipy.ndimage.correlate1d(mu_image, avg_window, 1, mu_image, mode=extend_mode)
    scipy.ndimage.correlate1d(image**2, avg_window, 0, var_image, mode=extend_mode)
    scipy.ndimage.correlate1d(var_image, avg_window, 1, var_image, mode=extend_mode)
    var_image = np.sqrt(np.abs(var_image - mu_image**2))
    return (image - mu_image)/(var_image + C), var_image, mu_image

def spatiotemporal_mscn(img_buffer,avg_window,extend_mode='mirror'):
    st_mean = np.zeros((img_buffer.shape))
    scipy.ndimage.correlate1d(img_buffer, avg_window, 0, st_mean, mode=extend_mode)
    return st_mean

def block_compute_lnl(block):
    block = block.astype(np.float32)
    avg_luminance = np.average(block.flatten()+1)
    block_transform =  block/(block+avg_luminance) #
#     block_mscn,_,_ = compute_image_mscn_transform(block_transform)
#     block_transform_brisque =compute_csf_brisque(block_transform,avg_luminance)
#     half_block_transform = cv2.resize(block_transform, dsize=(0, 0), fx=0.5, fy=0.5, interpolation=cv2.INTER_LANCZOS4)
#     half_avg_luminance = gmean(half_block_transform.flatten()+1e-4)
#     half_block_transform_brisque =compute_csf_brisque(half_block_transform,half_avg_luminance)  
#     brisque_feat = np.concatenate((block_transform_brisque,half_block_transform_brisque),0)
    return block_transform
def blockshaped(arr, nrows, ncols):
    """
    Return an array of shape (n, nrows, ncols) where
    n * nrows * ncols = arr.size

    If arr is a 2D array, the returned array should look like n subblocks with
    each subblock preserving the "physical" layout of arr.
    """
    h, w = arr.shape
    assert h % nrows == 0, "{} rows is not evenly divisble by {}".format(h, nrows)
    assert w % ncols == 0, "{} cols is not evenly divisble by {}".format(w, ncols)
    return (arr.reshape(h//nrows, nrows, -1, ncols)
               .swapaxes(1,2)
               .reshape(-1, nrows, ncols))

def unblockshaped(arr, h, w):
    """
    Return an array of shape (h, w) where
    h * w = arr.size

    If arr is of shape (n, nrows, ncols), n sublocks of shape (nrows, ncols),
    then the returned array preserves the "physical" layout of the sublocks.
    """
    n, nrows, ncols = arr.shape
    return (arr.reshape(h//nrows, -1, nrows, ncols)
               .swapaxes(1,2)
               .reshape(h, w))

def spatial_mscn(i,filenames,framenum,use_csf=True,linear=True):
    filename = filenames[i]
    name = os.path.basename(filename)
    print(name) 
    framenos = framenos_list[i]



    # SIZE of frames
    h,w = 2160,3840 
    print(h,w)
    if(h>w):
        h_temp = h
        h=w
        w = h_temp
        
    # SIZE of windows
    h_win,w_win = 45,45
    max_h,max_w = int((h//h_win)*h_win),int((w//w_win)*w_win)
    #percent by which the image is resized
    scale_percent = 0.5
    # dsize
    dsize = (int(scale_percent*h),int(scale_percent*w))

    # opening file object
    dis_file_object = open(filename)
    prevY_pq,_,_ = hdr_yuv_read(dis_file_object,framenum,h,w)
    count=1
    prevY_pq = prevY_pq.astype(np.float32)
    if(linear==True):
        y_pq_normalized = prevY_pq.astype(np.float32)/1024.0
        prevY_pq = eotf_PQ_BT2100(y_pq_normalized)
    Y_mscn,_,_ = compute_image_mscn_transform(prevY_pq)

#     h_indices = np.arange(h_win//2,Y_mscn.shape[0],h_win)
#     w_indices = np.arange(w_win//2,Y_mscn.shape[1],w_win)
#     xx,yy = np.meshgrid(h_indices,w_indices)
#     print(xx,yy)
#     xx = xx.flatten()
#     yy = yy.flatten()
    xx, yy = np.mgrid[h_win//2:h-h_win//2:h_win, w_win//2:w-w_win//2:w_win].reshape(2,-1).astype(int)
    print(xx)
    print(yy)
    print(len(xx))
    blocks = blockshaped(prevY_pq[:max_h,:max_w],h_win,w_win)
    block_lnl = Parallel(n_jobs=20,verbose=10)(delayed(block_compute_lnl)(block)\
                                                         for block in blocks) 

    Y = unblockshaped(blocks,max_h,max_w)
    Y_lnl = unblockshaped(np.asarray(block_lnl),max_h,max_w)
    
    Y_mscn,_,_ = compute_image_mscn_transform(Y)
    Y_lnl_mscn,_,_ = compute_image_mscn_transform(Y_lnl,C=1e-3)
    return Y, Y_lnl,Y_mscn,Y_lnl_mscn


    step = st_time_length
    cy, cx = np.mgrid[step:h-step*4:step*4, step:w-step*4:step*4].reshape(2,-1).astype(int) # these will be the centers of each block
    dcy, dcx = np.mgrid[step:dsize[0]-step*4:step*4, step:dsize[1]-step*4:step*4].reshape(2,-1).astype(int) # these will be the centers of each block

    
    prevY_pq_down = cv2.resize(prevY_pq,(dsize[1],dsize[0]),interpolation=cv2.INTER_CUBIC)

    img_buffer = np.zeros((st_time_length,prevY_pq.shape[0],prevY_pq.shape[1]))
    grad_img_buffer = np.zeros((st_time_length,prevY_pq.shape[0],prevY_pq.shape[1]))
    down_img_buffer =np.zeros((st_time_length,prevY_pq_down.shape[0],prevY_pq_down.shape[1]))
    graddown_img_buffer =np.zeros((st_time_length,prevY_pq_down.shape[0],prevY_pq_down.shape[1]))


    gradient_x = cv2.Sobel(prevY_pq,ddepth=-1,dx=1,dy=0)
    gradient_y = cv2.Sobel(prevY_pq,ddepth=-1,dx=0,dy=1)
    gradient_mag = np.sqrt(gradient_x**2+gradient_y**2)    

    
    gradient_x_down = cv2.Sobel(prevY_pq_down,ddepth=-1,dx=1,dy=0)
    gradient_y_down = cv2.Sobel(prevY_pq_down,ddepth=-1,dx=0,dy=1)
    gradient_mag_down = np.sqrt(gradient_x_down**2+gradient_y_down**2)    
    i = 0


        
    
    dY_mscn,_,_ = compute_image_mscn_transform(prevY_pq_down)
    gradY_mscn,_,_ = compute_image_mscn_transform(gradient_mag)
    dgradY_mscn,_,_ = compute_image_mscn_transform(gradient_mag_down)


    return

# %%
input_folder = '../../hdr_yuv'
csv_file = '../yuv_rw_info.csv'
csv_df = pd.read_csv(csv_file)
files = [os.path.join(input_folder,f) for f in csv_df["yuv"]]
for i,f in enumerate(files):
    print(i,f)
fps = csv_df["fps"]
framenos_list = csv_df["framenos"]
ws =csv_df["w"]
hs = csv_df["h"]
flag = 0
#    Parallel(n_jobs=5)(delayed(sts_fromfilename)(i,files,framenos_list,args.results_folder,use_csf=False) for i in range(len(files)))
Y, Y_lnl,Y_mscn,Y_lnl_mscn = spatial_mscn(123,files,10)
# Out:
# 0 ../../hdr_yuv/4k_cbr15Mbps_Blanc1.yuv
# 1 ../../hdr_yuv/4k_cbr15Mbps_Blanc2.yuv
# 2 ../../hdr_yuv/4k_cbr15Mbps_Blanc3.yuv
# 3 ../../hdr_yuv/4k_cbr15Mbps_Bonfire.yuv
# 4 ../../hdr_yuv/4k_cbr15Mbps_Bravia2.yuv
# 5 ../../hdr_yuv/4k_cbr15Mbps_Bravia3.yuv
# 6 ../../hdr_yuv/4k_cbr15Mbps_CargoBoat.yuv
# 7 ../../hdr_yuv/4k_cbr15Mbps_CenterPanorama.yuv
# 8 ../../hdr_yuv/4k_cbr15Mbps_Chasing1.yuv
# 9 ../../hdr_yuv/4k_cbr15Mbps_Chasing3.yuv
# 10 ../../hdr_yuv/4k_cbr15Mbps_Chasing4.yuv
# 11 ../../hdr_yuv/4k_cbr15Mbps_CourtYard.yuv
# 12 ../../hdr_yuv/4k_cbr15Mbps_Daylight1.yuv
# 13 ../../hdr_yuv/4k_cbr15Mbps_firework.yuv
# 14 ../../hdr_yuv/4k_cbr15Mbps_Fizzle1.yuv
# 15 ../../hdr_yuv/4k_cbr15Mbps_Fizzle2.yuv
# 16 ../../hdr_yuv/4k_cbr15Mbps_Flowers.yuv
# 17 ../../hdr_yuv/4k_cbr15Mbps_football10.yuv
# 18 ../../hdr_yuv/4k_cbr15Mbps_football1.yuv
# 19 ../../hdr_yuv/4k_cbr15Mbps_football2.yuv
# 20 ../../hdr_yuv/4k_cbr15Mbps_football3.yuv
# 21 ../../hdr_yuv/4k_cbr15Mbps_football4.yuv
# 22 ../../hdr_yuv/4k_cbr15Mbps_football5.yuv
# 23 ../../hdr_yuv/4k_cbr15Mbps_football6.yuv
# 24 ../../hdr_yuv/4k_cbr15Mbps_football7.yuv
# 25 ../../hdr_yuv/4k_cbr15Mbps_football8.yuv
# 26 ../../hdr_yuv/4k_cbr15Mbps_football9.yuv
# 27 ../../hdr_yuv/4k_cbr15Mbps_Furniture.yuv
# 28 ../../hdr_yuv/4k_cbr15Mbps_golf1.yuv
# 29 ../../hdr_yuv/4k_cbr15Mbps_golf2.yuv
# 30 ../../hdr_yuv/4k_cbr15Mbps_Light2.yuv
# 31 ../../hdr_yuv/4k_cbr15Mbps_Light3.yuv
# 32 ../../hdr_yuv/4k_cbr15Mbps_Light4.yuv
# 33 ../../hdr_yuv/4k_cbr15Mbps_NewYork1.yuv
# 34 ../../hdr_yuv/4k_cbr15Mbps_NewYork2.yuv
# 35 ../../hdr_yuv/4k_cbr15Mbps_NighTraffic.yuv
# 36 ../../hdr_yuv/4k_cbr15Mbps_OfficeBuilding.yuv
# 37 ../../hdr_yuv/4k_cbr15Mbps_Porsche.yuv
# 38 ../../hdr_yuv/4k_cbr15Mbps_Skyscraper.yuv
# 39 ../../hdr_yuv/4k_cbr15Mbps_Swordsmith1.yuv
# 40 ../../hdr_yuv/4k_cbr15Mbps_Swordsmith2.yuv
# 41 ../../hdr_yuv/4k_cbr15Mbps_UrbanLandmark.yuv
# 42 ../../hdr_yuv/4k_cbr15Mbps_Whale.yuv
# 43 ../../hdr_yuv/4k_cbr3Mbps_Blanc1.yuv
# 44 ../../hdr_yuv/4k_cbr3Mbps_Blanc2.yuv
# 45 ../../hdr_yuv/4k_cbr3Mbps_Blanc3.yuv
# 46 ../../hdr_yuv/4k_cbr3Mbps_Bonfire.yuv
# 47 ../../hdr_yuv/4k_cbr3Mbps_Bravia2.yuv
# 48 ../../hdr_yuv/4k_cbr3Mbps_Bravia3.yuv
# 49 ../../hdr_yuv/4k_cbr3Mbps_CargoBoat.yuv
# 50 ../../hdr_yuv/4k_cbr3Mbps_CenterPanorama.yuv
# 51 ../../hdr_yuv/4k_cbr3Mbps_Chasing1.yuv
# 52 ../../hdr_yuv/4k_cbr3Mbps_Chasing3.yuv
# 53 ../../hdr_yuv/4k_cbr3Mbps_Chasing4.yuv
# 54 ../../hdr_yuv/4k_cbr3Mbps_CourtYard.yuv
# 55 ../../hdr_yuv/4k_cbr3Mbps_Daylight1.yuv
# 56 ../../hdr_yuv/4k_cbr3Mbps_firework.yuv
# 57 ../../hdr_yuv/4k_cbr3Mbps_Fizzle1.yuv
# 58 ../../hdr_yuv/4k_cbr3Mbps_Fizzle2.yuv
# 59 ../../hdr_yuv/4k_cbr3Mbps_Flowers.yuv
# 60 ../../hdr_yuv/4k_cbr3Mbps_football10.yuv
# 61 ../../hdr_yuv/4k_cbr3Mbps_football1.yuv
# 62 ../../hdr_yuv/4k_cbr3Mbps_football2.yuv
# 63 ../../hdr_yuv/4k_cbr3Mbps_football3.yuv
# 64 ../../hdr_yuv/4k_cbr3Mbps_football4.yuv
# 65 ../../hdr_yuv/4k_cbr3Mbps_football5.yuv
# 66 ../../hdr_yuv/4k_cbr3Mbps_football6.yuv
# 67 ../../hdr_yuv/4k_cbr3Mbps_football7.yuv
# 68 ../../hdr_yuv/4k_cbr3Mbps_football8.yuv
# 69 ../../hdr_yuv/4k_cbr3Mbps_football9.yuv
# 70 ../../hdr_yuv/4k_cbr3Mbps_Furniture.yuv
# 71 ../../hdr_yuv/4k_cbr3Mbps_golf1.yuv
# 72 ../../hdr_yuv/4k_cbr3Mbps_golf2.yuv
# 73 ../../hdr_yuv/4k_cbr3Mbps_Light2.yuv
# 74 ../../hdr_yuv/4k_cbr3Mbps_Light3.yuv
# 75 ../../hdr_yuv/4k_cbr3Mbps_Light4.yuv
# 76 ../../hdr_yuv/4k_cbr3Mbps_NewYork1.yuv
# 77 ../../hdr_yuv/4k_cbr3Mbps_NewYork2.yuv
# 78 ../../hdr_yuv/4k_cbr3Mbps_NighTraffic.yuv
# 79 ../../hdr_yuv/4k_cbr3Mbps_OfficeBuilding.yuv
# 80 ../../hdr_yuv/4k_cbr3Mbps_Porsche.yuv
# 81 ../../hdr_yuv/4k_cbr3Mbps_Skyscraper.yuv
# 82 ../../hdr_yuv/4k_cbr3Mbps_Swordsmith1.yuv
# 83 ../../hdr_yuv/4k_cbr3Mbps_Swordsmith2.yuv
# 84 ../../hdr_yuv/4k_cbr3Mbps_UrbanLandmark.yuv
# 85 ../../hdr_yuv/4k_cbr3Mbps_Whale.yuv
# 86 ../../hdr_yuv/reference_Blanc1.yuv
# 87 ../../hdr_yuv/reference_Blanc2.yuv
# 88 ../../hdr_yuv/reference_Blanc3.yuv
# 89 ../../hdr_yuv/reference_Bonfire.yuv
# 90 ../../hdr_yuv/reference_Bravia2.yuv
# 91 ../../hdr_yuv/reference_Bravia3.yuv
# 92 ../../hdr_yuv/reference_CargoBoat.yuv
# 93 ../../hdr_yuv/reference_CenterPanorama.yuv
# 94 ../../hdr_yuv/reference_Chasing1.yuv
# 95 ../../hdr_yuv/reference_Chasing3.yuv
# 96 ../../hdr_yuv/reference_Chasing4.yuv
# 97 ../../hdr_yuv/reference_CourtYard.yuv
# 98 ../../hdr_yuv/reference_Daylight1.yuv
# 99 ../../hdr_yuv/reference_firework.yuv
# 100 ../../hdr_yuv/reference_Fizzle1.yuv
# 101 ../../hdr_yuv/reference_Fizzle2.yuv
# 102 ../../hdr_yuv/reference_Flowers.yuv
# 103 ../../hdr_yuv/reference_football10.yuv
# 104 ../../hdr_yuv/reference_football1.yuv
# 105 ../../hdr_yuv/reference_football2.yuv
# 106 ../../hdr_yuv/reference_football3.yuv
# 107 ../../hdr_yuv/reference_football4.yuv
# 108 ../../hdr_yuv/reference_football5.yuv
# 109 ../../hdr_yuv/reference_football6.yuv
# 110 ../../hdr_yuv/reference_football7.yuv
# 111 ../../hdr_yuv/reference_football8.yuv
# 112 ../../hdr_yuv/reference_football9.yuv
# 113 ../../hdr_yuv/reference_Furniture.yuv
# 114 ../../hdr_yuv/reference_golf1.yuv
# 115 ../../hdr_yuv/reference_golf2.yuv
# 116 ../../hdr_yuv/reference_Light2.yuv
# 117 ../../hdr_yuv/reference_Light3.yuv
# 118 ../../hdr_yuv/reference_Light4.yuv
# 119 ../../hdr_yuv/reference_NewYork1.yuv
# 120 ../../hdr_yuv/reference_NewYork2.yuv
# 121 ../../hdr_yuv/reference_NighTraffic.yuv
# 122 ../../hdr_yuv/reference_OfficeBuilding.yuv
# 123 ../../hdr_yuv/reference_Porsche.yuv
# 124 ../../hdr_yuv/reference_Skyscraper.yuv
# 125 ../../hdr_yuv/reference_Swordsmith1.yuv
# 126 ../../hdr_yuv/reference_Swordsmith2.yuv
# 127 ../../hdr_yuv/reference_UrbanLandmark.yuv
# 128 ../../hdr_yuv/reference_Whale.yuv
# reference_Porsche.yuv
# 2160 3840
# [  22   22   22 ..., 2137 2137 2137]
# [  22   67  112 ..., 3712 3757 3802]
# 4080
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.0091s.) Setting batch_size=2.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done  21 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.0670s.) Setting batch_size=4.
# [Parallel(n_jobs=20)]: Done  33 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done  50 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done  76 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 106 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.0733s.) Setting batch_size=8.
# [Parallel(n_jobs=20)]: Done 152 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 220 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.1067s.) Setting batch_size=16.
# [Parallel(n_jobs=20)]: Done 296 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=20)]: Done 448 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=20)]: Done 600 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.1218s.) Setting batch_size=32.
# [Parallel(n_jobs=20)]: Done 936 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.1441s.) Setting batch_size=64.
# [Parallel(n_jobs=20)]: Done 1304 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=20)]: Done 2040 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=20)]: Batch computation too fast (0.1998s.) Setting batch_size=128.
# [Parallel(n_jobs=20)]: Done 3032 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=20)]: Done 3813 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=20)]: Done 3838 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=20)]: Done 3865 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=20)]: Done 3892 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=20)]: Done 3921 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=20)]: Done 3950 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=20)]: Done 3981 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=20)]: Done 4012 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=20)]: Done 4080 out of 4080 | elapsed:    1.6s finished

# %%
Yplot = np.concatenate(Y_lnl_mscn).flatten()

# %%
from scipy.stats import kurtosis
alpha,sigma = ChipQA.save_stats.estimateggdparam(Yplot-np.mean(Yplot))
kurt = kurtosis(Yplot-np.mean(Yplot),fisher=False)
x = np.arange(-2,2,0.01)
Y_ggd = ChipQA.save_stats.generate_ggd(x,alpha,sigma)

# %%
# %matplotlib notebook
# %matplotlib notebook

# plt.hist(np.concatenate(Y_lnl_mscn[0]).flatten(),bins='auto',histtype='step',density=True)
#plt.hist(np.concatenate(Y_lnl_mscn).flatten(),bins='auto',histtype='step',density=True)
# plt.hist(np.concatenate(Y_lnl_mscn[67]).flatten(),bins='auto',histtype='step',density=True)


plt.clf()
plt.hist(Yplot-np.mean(Yplot),bins='auto',histtype='step',label=r'$\alpha=$'+str(alpha)[:4]+'\nkurtosis='+str(kurt)[:4],density=True)
plt.plot(x,Y_ggd)
plt.ylabel('Empirical distribution')
plt.xlabel('MSCN')
plt.title('Histogram of LNL MSCN')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.clf()
plt.imshow(Y,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.clf()
plt.imshow(Y_lnl,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.colors import Normalize
plt.figure()
plt.clf()
plt.imshow(Y_mscn,norm=Normalize(),cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.clf()
plt.imshow(Y_lnl_mscn,norm=Normalize(),cmap='gray')
# Out:
# <img src="data:," width="0">

# %%
x = np.arange(0,1024)
y = x/(x+512)
plt.figure()
plt.clf()
plt.xlabel('L')
plt.ylabel('R')
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.arange(0,1024)
y = 1/(1+np.exp(-10e-3*(x-512)))
plt.figure()
plt.clf()
plt.xlabel('L')
plt.ylabel('R')
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# -0.12145029818606382
